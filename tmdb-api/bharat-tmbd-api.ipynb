# %%
import requests
import pandas as pd

# %%
base_url = "https://api.themoviedb.org" # TMDb api site
with open("/Users/bharat/Documents/Data Science/LearningFuze VS Code/api_keys/TMDbAPIKey.txt", "r") as file: # load API key
        api_key = file.read() # set API key as variable
query_string = "star%20wars" # string to query from API
page = 1 # default page of results
api_url = f"/3/search/movie?api_key={api_key}&query={query_string}&page={page}" # resolved API URL part

full_url = base_url + api_url # constructing full URL to call
results = requests.get(full_url) # results from API
results_json = results.json() # convert to JSON

all_results = [] # create empty list to grab results from all pages

for page in range(1, results_json['total_pages'] + 1): # cycle through pages and get results from each page
        page = page
        full_url = base_url + api_url
        results = requests.get(full_url)
        page_results = results.json()
        page_result_list = page_results['results']
        all_results.extend(page_result_list) # extend list with each list of results on each page
        
star_wars_df = pd.DataFrame(all_results) # format the JSON object into a DataFrame

star_wars_df
# Out:
#      adult                     backdrop_path                        genre_ids  \
# 0    False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg                    [12, 28, 878]
# 1    False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                    [12, 28, 878]
# 2    False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                    [12, 28, 878]
# 3    False  /auJKGst3vXpJozHZh4nMFs0xWIU.jpg                    [12, 28, 878]
# 4    False  /ojHCeDULAkQK25700fhRU75Tur2.jpg                    [878, 12, 28]
# ..     ...                               ...                              ...
# 215  False  /ae9xlnkS2qb5Dy9Mtlu68AWh42O.jpg          [14, 878, 10751, 10770]
# 216  False  /oJNrNkSb6NBRlOCplioFQhvR7M4.jpg                    [878, 16, 35]
# 217  False  /f53Jujiap580mgfefID0T0g2e17.jpg      [16, 10751, 878, 35, 10770]
# 218  False  /qnTeIxszgMsFJmPXVGLtj7rxVxN.jpg  [16, 35, 10751, 878, 12, 10770]
# 219  False  /ucEQXe6wPpPhgcJh4oXOAvX1lnb.jpg         [16, 10751, 878, 12, 35]
#
#          id original_language                       original_title  \
# 0        11                en                            Star Wars
# 1    140607                en         Star Wars: The Force Awakens
# 2    181808                en             Star Wars: The Last Jedi
# 3    181812                en     Star Wars: The Rise of Skywalker
# 4    348350                en              Solo: A Star Wars Story
# ..      ...               ...                                  ...
# 215   74849                en        The Star Wars Holiday Special
# 216   42982                en  Robot Chicken: Star Wars Episode II
# 217  857702                en      LEGO Star Wars Terrifying Tales
# 218  392216                en          Phineas and Ferb: Star Wars
# 219  732670                en       LEGO Star Wars Holiday Special
#
#                                               overview  popularity  \
# 0    Princess Leia is captured and held hostage by ...     112.663
# 1    Thirty years after defeating the Galactic Empi...      74.254
# 2    Rey develops her newly discovered abilities wi...      66.387
# 3    The surviving Resistance faces the First Order...      57.878
# 4    Through a series of daring escapades deep with...      36.338
# ..                                                 ...         ...
# 215  Luke Skywalker and Han Solo battle evil Imperi...      10.412
# 216  Seth Green and Matthew Senreich serve up more ...       8.811
# 217  Poe Dameron and BB-8 must face the greedy crim...      10.740
# 218  Phineas and Ferb become the galaxy's unlikelie...      10.892
# 219  As her friends prep for a Life Day holiday cel...      11.055
#
#                           poster_path release_date  \
# 0    /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 1    /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg   2015-12-15
# 2    /ySaaKHOLAQU5HoZqWmzDIj1VvZ1.jpg   2017-12-13
# 3    /db32LaOibwEliAmSL2jjDF6oDdj.jpg   2019-12-18
# 4    /4oD6VEccFkorEBTEDXtpLAaz0Rl.jpg   2018-05-15
# ..                                ...          ...
# 215  /eRSKviGcTqHd34vCLjcztJF6Eaw.jpg   1978-11-17
# 216  /dM5eCurdAXYd3Dvyr9Rz2YSj3rJ.jpg   2008-11-16
# 217  /fYiaBZDjyXjvlY6EDZMAxIhBO1I.jpg   2021-10-01
# 218  /2XGlp5x232CeZM0PVjMMYQcXViA.jpg   2014-07-26
# 219  /zyzJSI7UZZzz5Toj10rYGF5689z.jpg   2020-11-17
#
#                                    title  video  vote_average  vote_count
# 0                              Star Wars  False         8.200       20864
# 1           Star Wars: The Force Awakens  False         7.300       19524
# 2               Star Wars: The Last Jedi  False         6.785       15416
# 3       Star Wars: The Rise of Skywalker  False         6.300       10024
# 4                Solo: A Star Wars Story  False         6.556        8612
# ..                                   ...    ...           ...         ...
# 215        The Star Wars Holiday Special  False         3.351         467
# 216  Robot Chicken: Star Wars Episode II  False         7.500         141
# 217      LEGO Star Wars Terrifying Tales  False         6.842         250
# 218          Phineas and Ferb: Star Wars  False         7.100         206
# 219       LEGO Star Wars Holiday Special  False         6.500         329
#
# [220 rows x 14 columns]

# %%
star_wars_df.sort_values(by="popularity",ascending=False) # sort the movies in the DataFrame by popularity (highest to lowest)
# Out:
#      adult                     backdrop_path      genre_ids      id  \
# 0    False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg  [12, 28, 878]      11
# 200  False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg  [12, 28, 878]      11
# 100  False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg  [12, 28, 878]      11
# 140  False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg  [12, 28, 878]      11
# 80   False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg  [12, 28, 878]      11
# ..     ...                               ...            ...     ...
# 194  False  /g0dk8y03ejiSzQFKoMKCI6DRwl9.jpg       [99, 18]  956879
# 14   False  /g0dk8y03ejiSzQFKoMKCI6DRwl9.jpg       [99, 18]  956879
# 154  False  /g0dk8y03ejiSzQFKoMKCI6DRwl9.jpg       [99, 18]  956879
# 34   False  /g0dk8y03ejiSzQFKoMKCI6DRwl9.jpg       [99, 18]  956879
# 54   False  /g0dk8y03ejiSzQFKoMKCI6DRwl9.jpg       [99, 18]  956879
#
#     original_language                 original_title  \
# 0                  en                      Star Wars
# 200                en                      Star Wars
# 100                en                      Star Wars
# 140                en                      Star Wars
# 80                 en                      Star Wars
# ..                ...                            ...
# 194                fr  Dans l’ombre du Star Wars Kid
# 14                 fr  Dans l’ombre du Star Wars Kid
# 154                fr  Dans l’ombre du Star Wars Kid
# 34                 fr  Dans l’ombre du Star Wars Kid
# 54                 fr  Dans l’ombre du Star Wars Kid
#
#                                               overview  popularity  \
# 0    Princess Leia is captured and held hostage by ...     112.663
# 200  Princess Leia is captured and held hostage by ...     112.663
# 100  Princess Leia is captured and held hostage by ...     112.663
# 140  Princess Leia is captured and held hostage by ...     112.663
# 80   Princess Leia is captured and held hostage by ...     112.663
# ..                                                 ...         ...
# 194  Ghyslain Raza, better known as the “Star Wars ...       0.967
# 14   Ghyslain Raza, better known as the “Star Wars ...       0.967
# 154  Ghyslain Raza, better known as the “Star Wars ...       0.967
# 34   Ghyslain Raza, better known as the “Star Wars ...       0.967
# 54   Ghyslain Raza, better known as the “Star Wars ...       0.967
#
#                           poster_path release_date  \
# 0    /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 200  /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 100  /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 140  /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 80   /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# ..                                ...          ...
# 194  /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
# 14   /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
# 154  /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
# 34   /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
# 54   /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
#
#                                               title  video  vote_average  \
# 0                                         Star Wars  False           8.2
# 200                                       Star Wars  False           8.2
# 100                                       Star Wars  False           8.2
# 140                                       Star Wars  False           8.2
# 80                                        Star Wars  False           8.2
# ..                                              ...    ...           ...
# 194  Star Wars Kid: The Rise of the Digital Shadows  False           7.6
# 14   Star Wars Kid: The Rise of the Digital Shadows  False           7.6
# 154  Star Wars Kid: The Rise of the Digital Shadows  False           7.6
# 34   Star Wars Kid: The Rise of the Digital Shadows  False           7.6
# 54   Star Wars Kid: The Rise of the Digital Shadows  False           7.6
#
#      vote_count
# 0         20864
# 200       20864
# 100       20864
# 140       20864
# 80        20864
# ..          ...
# 194           9
# 14            9
# 154           9
# 34            9
# 54            9
#
# [220 rows x 14 columns]
