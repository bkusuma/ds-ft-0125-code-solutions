# %% [markdown]
# # Pandas Exercises
#
# ### 1. Import numpy, pandas, etc

# %%
import numpy as np

import pandas as pd

# %% [markdown]
# ### 2. Load the data from the file `"Loan payments data.csv"` into a variable called `"loans"`

# %%
loans = pd.read_csv("Loan payments data.csv")
loans
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 0     10/7/2016   9/14/2016 19:31            NaN   45  High School or Below
# 1     10/7/2016    10/7/2016 9:00            NaN   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58            NaN   33              Bechalor
# 3     9/22/2016   9/22/2016 20:00            NaN   27               college
# 4     10/8/2016   9/23/2016 21:36            NaN   28               college
# ..          ...               ...            ...  ...                   ...
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender       City
# 0      male  Vancouver
# 1    female        NYC
# 2    female    Houston
# 3      male        NYC
# 4    female    Houston
# ..      ...        ...
# 495    male    Houston
# 496    male         LA
# 497    male       Maui
# 498  female        NYC
# 499    male    Calgary
#
# [500 rows x 12 columns]

# %% [markdown]
# ### 3. Display the first 7 rows of the data

# %%
loans.head(7)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender  \
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female
# 5   9/9/2016 13:45            NaN   35       Master or Above    male
# 6  10/7/2016 23:07            NaN   29               college    male
#
#         City
# 0  Vancouver
# 1        NYC
# 2    Houston
# 3        NYC
# 4    Houston
# 5    Houston
# 6       Maui

# %% [markdown]
# ### 4. Display the last 3 rows of the data

# %%
loans.tail(3)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender     City
# 497    male     Maui
# 498  female      NYC
# 499    male  Calgary

# %% [markdown]
# ### 5. Select 25% of the data, picked randomly and display the first 5 rows

# %%
loans.sample(frac=0.25).head(5)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 64   xqd20160065             PAIDOFF        800     15      9/11/2016
# 25   xqd20160026             PAIDOFF       1000     30      9/10/2016
# 166  xqd20160167             PAIDOFF       1000     30      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 45   xqd20160046             PAIDOFF        800      7      9/11/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 64    9/25/2016   9/25/2016 14:38            NaN   24  High School or Below
# 25    10/9/2016   9/29/2016 12:18            NaN   29  High School or Below
# 166  10/11/2016  10/11/2016 16:00            NaN   28               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 45    9/17/2016   9/12/2016 22:17            NaN   35  High School or Below
#
#      Gender     City
# 64     male  Houston
# 25     male     Maui
# 166    male  Houston
# 498  female      NYC
# 45     male     Maui

# %% [markdown]
# ### 6. Sample 10 rows and display it

# %%
loans.sample(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 43   xqd20160044             PAIDOFF       1000     15      9/11/2016
# 308  xqd20160309          COLLECTION       1000     30      9/10/2016
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 458  xqd20160459  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 302  xqd20160303          COLLECTION       1000     30       9/9/2016
# 357  xqd20160358          COLLECTION       1000     30      9/11/2016
# 353  xqd20160354          COLLECTION       1000     30      9/11/2016
# 255  xqd20160256             PAIDOFF       1000     30      9/13/2016
# 419  xqd20160420  COLLECTION_PAIDOFF       1000     30      9/11/2016
# 374  xqd20182575          COLLECTION       1000     30      9/11/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 43    9/25/2016   9/20/2016 15:00            NaN   30               college
# 308   10/9/2016               NaN           60.0   33               college
# 400   10/8/2016  10/10/2016 11:45            2.0   26               college
# 458  10/11/2016  10/13/2016 15:10            2.0   34               college
# 302   10/8/2016               NaN           61.0   33  High School or Below
# 357  10/10/2016               NaN           59.0   26              Bechalor
# 353  10/10/2016               NaN           59.0   41  High School or Below
# 255  10/12/2016   10/8/2016 15:51            NaN   31               college
# 419  10/10/2016   11/4/2016 15:37           25.0   33  High School or Below
# 374  10/10/2016               NaN           59.0   29               college
#
#     Gender       City
# 43    male  Vancouver
# 308   male         LA
# 400   male       Maui
# 458   male    Houston
# 302   male    Calgary
# 357   male         LA
# 353   male       Maui
# 255   male  Vancouver
# 419   male        NYC
# 374   male       Maui

# %% [markdown]
# ### 7. Display the value counts of the `loan_status` column and the `City` column

# %%
loans["loan_status"].value_counts()
# Out:
# loan_status
# PAIDOFF               300
# COLLECTION            100
# COLLECTION_PAIDOFF    100
# Name: count, dtype: int64

# %%
loans["City"].value_counts()
# Out:
# City
# Houston      100
# LA            90
# Vancouver     82
# Maui          78
# Calgary       76
# NYC           74
# Name: count, dtype: int64

# %% [markdown]
# ### 8. Display only the 201st row

# %%
loans.loc[200]
# Out:
# Loan_ID              xqd20160201
# loan_status              PAIDOFF
# Principal                   1000
# terms                         15
# effective_date         9/12/2016
# due_date               9/26/2016
# paid_off_time     9/20/2016 8:26
# past_due_days                NaN
# age                           30
# education                college
# Gender                      male
# City                          LA
# Name: 200, dtype: object

# %% [markdown]
# ### 9. Display only the `education` column

# %%
loans["education"]
# Out:
# 0      High School or Below
# 1                  Bechalor
# 2                  Bechalor
# 3                   college
# 4                   college
#                ...
# 495    High School or Below
# 496    High School or Below
# 497                 college
# 498                 college
# 499    High School or Below
# Name: education, Length: 500, dtype: object

# %% [markdown]
# ### 10. Display only the `loan_status` column

# %%
loans["loan_status"]
# Out:
# 0                 PAIDOFF
# 1                 PAIDOFF
# 2                 PAIDOFF
# 3                 PAIDOFF
# 4                 PAIDOFF
#               ...
# 495    COLLECTION_PAIDOFF
# 496    COLLECTION_PAIDOFF
# 497    COLLECTION_PAIDOFF
# 498    COLLECTION_PAIDOFF
# 499    COLLECTION_PAIDOFF
# Name: loan_status, Length: 500, dtype: object

# %% [markdown]
# ### 11. Display only the 9th column by index
#
# ***(hint: remember that Python is 0-indexed!)***

# %%
loans.iloc[8]
# Out:
# Loan_ID               xqd20160909
# loan_status               PAIDOFF
# Principal                    1000
# terms                          30
# effective_date           9/9/2016
# due_date                10/8/2016
# paid_off_time     10/8/2016 16:00
# past_due_days                 NaN
# age                            28
# education                 college
# Gender                       male
# City                    Vancouver
# Name: 8, dtype: object

# %% [markdown]
# ### 12. Display the 3rd through 7th rows by index slicing

# %%
loans.iloc[2:7]
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age        education  Gender     City
# 2  9/25/2016 16:58            NaN   33         Bechalor  female  Houston
# 3  9/22/2016 20:00            NaN   27          college    male      NYC
# 4  9/23/2016 21:36            NaN   28          college  female  Houston
# 5   9/9/2016 13:45            NaN   35  Master or Above    male  Houston
# 6  10/7/2016 23:07            NaN   29          college    male     Maui

# %% [markdown]
# ### 13. Display the last 3 columns by index slicing

# %%
loans.iloc[-3:]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender     City
# 497    male     Maui
# 498  female      NYC
# 499    male  Calgary

# %% [markdown]
# ### 14. Display only the rows where `Gender` is `female`

# %%
loans.loc[loans["Gender"] == "female"]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# 13   xqd20160014             PAIDOFF        900      7      9/10/2016
# 21   xqd20160022             PAIDOFF       1000     30      9/10/2016
# ..           ...                 ...        ...    ...            ...
# 465  xqd20169466  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 474  xqd20160475  COLLECTION_PAIDOFF        800     15      9/12/2016
# 475  xqd20160476  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 476  xqd20160477  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 1     10/7/2016    10/7/2016 9:00            NaN   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58            NaN   33              Bechalor
# 4     10/8/2016   9/23/2016 21:36            NaN   28               college
# 13    9/16/2016   9/13/2016 21:57            NaN   26               college
# 21    10/9/2016   10/8/2016 17:09            NaN   43  High School or Below
# ..          ...               ...            ...  ...                   ...
# 465  10/11/2016  10/12/2016 12:54            1.0   49  High School or Below
# 474   9/26/2016   9/28/2016 11:34            2.0   26  High School or Below
# 475  10/11/2016   11/9/2016 18:12           29.0   35               college
# 476  10/26/2016  10/31/2016 13:07            5.0   46               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
#
#      Gender       City
# 1    female        NYC
# 2    female    Houston
# 4    female    Houston
# 13   female    Houston
# 21   female  Vancouver
# ..      ...        ...
# 465  female    Calgary
# 474  female  Vancouver
# 475  female       Maui
# 476  female       Maui
# 498  female        NYC
#
# [77 rows x 12 columns]

# %% [markdown]
# ### 15. Display only the rows where `education` is `college` AND `City` is `NYC`

# %%
# loans.loc[loans["education"] == "college"][loans["City"] == "NYC"]
loans.loc[(loans["education"] == "college") & (loans["City"] == "NYC")]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 7    xqd20160008             PAIDOFF       1000     30       9/9/2016
# 24   xqd20160025             PAIDOFF       1000     30      9/10/2016
# 31   xqd20160032             PAIDOFF       1000     30      9/11/2016
# 41   xqd20160042             PAIDOFF        800     15      9/11/2016
# 65   xqd20160066             PAIDOFF        900     15      9/11/2016
# 68   xqd20160069             PAIDOFF        300      7      9/11/2016
# 73   xqd20160074             PAIDOFF       1000     15      9/11/2016
# 83   xqd20160084             PAIDOFF        800     15      9/11/2016
# 101  xqd20160102             PAIDOFF        800     15      9/11/2016
# 104  xqd20160105             PAIDOFF       1000     15      9/11/2016
# 108  xqd20160109             PAIDOFF       1000     30      9/11/2016
# 122  xqd20160123             PAIDOFF       1000     15      9/11/2016
# 152  xqd20160153             PAIDOFF        500     15      9/12/2016
# 154  xqd20160155             PAIDOFF       1000     30      9/12/2016
# 163  xqd28160164             PAIDOFF       1000     15      9/12/2016
# 195  xqd20160196             PAIDOFF       1000     30      9/12/2016
# 204  xqd20160205             PAIDOFF       1000     30      9/12/2016
# 206  xqd20160207             PAIDOFF       1000     30      9/12/2016
# 215  xqd20160216             PAIDOFF       1000     30      9/12/2016
# 220  xqd20160221             PAIDOFF       1000     15      9/12/2016
# 271  xqd20160272             PAIDOFF       1000     30      9/14/2016
# 275  xqd20160276             PAIDOFF        800     15      9/14/2016
# 314  xqd20160315          COLLECTION       1000     30      9/10/2016
# 323  xqd20160324          COLLECTION        800     15      9/10/2016
# 331  xqd20160332          COLLECTION        800     15      9/11/2016
# 334  xqd20160335          COLLECTION       1000     30      9/11/2016
# 363  xqd20160364          COLLECTION       1000     15      9/11/2016
# 364  xqd20160365          COLLECTION        800     15      9/11/2016
# 378  xqd20197340          COLLECTION       1000     30      9/11/2016
# 390  xqd20160391          COLLECTION       1000     15      9/11/2016
# 456  xqd20160457  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 459  xqd20160460  COLLECTION_PAIDOFF        800     15      9/12/2016
# 482  xqd20160483  COLLECTION_PAIDOFF        800     15      9/12/2016
# 488  xqd20160489  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age education  Gender City
# 3     9/22/2016   9/22/2016 20:00            NaN   27   college    male  NYC
# 7     10/8/2016   10/5/2016 20:33            NaN   36   college    male  NYC
# 24    10/9/2016   10/3/2016 12:50            NaN   26   college    male  NYC
# 31   10/10/2016   10/7/2016 21:48            NaN   37   college    male  NYC
# 41    9/25/2016   9/25/2016 14:36            NaN   30   college    male  NYC
# 65    9/25/2016   9/25/2016 23:00            NaN   28   college    male  NYC
# 68    9/17/2016   9/14/2016 22:05            NaN   35   college    male  NYC
# 73    9/25/2016    9/25/2016 9:00            NaN   34   college    male  NYC
# 83    9/25/2016   9/25/2016 13:00            NaN   33   college    male  NYC
# 101   9/25/2016    9/25/2016 9:00            NaN   38   college    male  NYC
# 104   9/25/2016   9/22/2016 13:15            NaN   35   college    male  NYC
# 108  10/10/2016   10/9/2016 13:05            NaN   28   college    male  NYC
# 122  10/25/2016   10/25/2016 9:00            NaN   20   college    male  NYC
# 152   9/26/2016   9/13/2016 20:17            NaN   23   college  female  NYC
# 154  10/11/2016   10/10/2016 7:01            NaN   34   college    male  NYC
# 163   9/26/2016    9/26/2016 9:00            NaN   27   college  female  NYC
# 195  10/11/2016  10/10/2016 15:49            NaN   24   college    male  NYC
# 204  10/11/2016   10/11/2016 9:01            NaN   20   college    male  NYC
# 206  11/10/2016  11/10/2016 13:00            NaN   26   college    male  NYC
# 215  11/10/2016  11/10/2016 16:00            NaN   29   college  female  NYC
# 220   9/26/2016   9/26/2016 23:00            NaN   35   college    male  NYC
# 271  10/13/2016   10/8/2016 17:12            NaN   32   college  female  NYC
# 275   9/28/2016   9/27/2016 15:52            NaN   44   college    male  NYC
# 314   10/9/2016               NaN           60.0   24   college    male  NYC
# 323   9/24/2016               NaN           75.0   32   college    male  NYC
# 331   9/25/2016               NaN           74.0   27   college    male  NYC
# 334  10/10/2016               NaN           59.0   38   college  female  NYC
# 363   9/25/2016               NaN           74.0   26   college    male  NYC
# 364   9/25/2016               NaN           74.0   22   college    male  NYC
# 378  10/10/2016               NaN           59.0   30   college    male  NYC
# 390   9/25/2016               NaN           74.0   30   college    male  NYC
# 456  10/11/2016  11/18/2016 15:52           38.0   25   college    male  NYC
# 459   9/26/2016   9/28/2016 13:36            2.0   33   college    male  NYC
# 482   9/26/2016   9/27/2016 11:40            1.0   47   college    male  NYC
# 488   9/26/2016   10/9/2016 19:30           13.0   45   college    male  NYC
# 498  11/10/2016  11/11/2016 22:40            1.0   38   college  female  NYC

# %% [markdown]
# ### 16. Display only the rows where `age` is larger than 32

# %%
loans.loc[loans["age"] > 32]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 5    xqd20160706             PAIDOFF        300      7       9/9/2016
# 7    xqd20160008             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 487  xqd20160488  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 488  xqd20160489  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 489  xqd20160490  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 490  xqd20160491  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 0     10/7/2016   9/14/2016 19:31            NaN   45  High School or Below
# 1     10/7/2016    10/7/2016 9:00            NaN   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58            NaN   33              Bechalor
# 5     9/15/2016    9/9/2016 13:45            NaN   35       Master or Above
# 7     10/8/2016   10/5/2016 20:33            NaN   36               college
# ..          ...               ...            ...  ...                   ...
# 487  10/11/2016  10/13/2016 12:02            2.0   35              Bechalor
# 488   9/26/2016   10/9/2016 19:30           13.0   45               college
# 489  10/11/2016  10/12/2016 18:04            1.0   36               college
# 490  10/11/2016  10/17/2016 10:53            6.0   38  High School or Below
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
#
#      Gender       City
# 0      male  Vancouver
# 1    female        NYC
# 2    female    Houston
# 5      male    Houston
# 7      male        NYC
# ..      ...        ...
# 487    male    Calgary
# 488    male        NYC
# 489    male       Maui
# 490    male    Calgary
# 498  female        NYC
#
# [188 rows x 12 columns]

# %% [markdown]
# ### 17.  Display the rows where there is a past-due of larger than a week and only display the `due_date` and `past_due_days` columns

# %%
loans.loc[loans["past_due_days"] > 7][["past_due_days", "due_date"]]
# Out:
#      past_due_days    due_date
# 300           76.0   9/23/2016
# 301           61.0   10/8/2016
# 302           61.0   10/8/2016
# 303           76.0   9/23/2016
# 304           76.0   9/23/2016
# ..             ...         ...
# 488           13.0   9/26/2016
# 491           29.0  10/11/2016
# 492           14.0  10/11/2016
# 496           14.0   9/26/2016
# 499            8.0  10/11/2016
#
# [128 rows x 2 columns]
