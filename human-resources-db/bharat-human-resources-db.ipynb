# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("hr.db") # connect to database

# %% [markdown]
# Retrieve table names from the database (hr.db).

# %%
q = """
SELECT name
FROM sqlite_master
WHERE type='table';
"""
# create query to find tables in database

pd.read_sql(q, conn)
# Out:
#        name
# 0  employee

# %% [markdown]
# Retrieve EmployeeNumber, Department, Age, Gender, and Attrition for employees in sales department from the Employee table; save that information into a dataframe named ‘sales’.

# %%
q = """
SELECT *
FROM employee;
"""
# create query to find features of employee table

pd.read_sql(q, conn)
# Out:
#       index  Age Attrition              Department  DistanceFromHome  \
# 0         0   41       Yes                   Sales                 1
# 1         1   49        No  Research & Development                 8
# 2         2   37       Yes  Research & Development                 2
# 3         3   33        No  Research & Development                 3
# 4         4   27        No  Research & Development                 2
# ...     ...  ...       ...                     ...               ...
# 1465   1465   36      None  Research & Development                23
# 1466   1466   39        No  Research & Development                 6
# 1467   1467   27        No  Research & Development                 4
# 1468   1468   49        No                   Sales                 2
# 1469   1469   34        No  Research & Development                 8
#
#       Education EducationField  EmployeeCount  EmployeeNumber  Gender  ...  \
# 0             2  Life Sciences              1               1  Female  ...
# 1             1  Life Sciences              1               2    Male  ...
# 2             2          Other              1               4    Male  ...
# 3             4  Life Sciences              1               5  Female  ...
# 4             1        Medical              1               7    Male  ...
# ...         ...            ...            ...             ...     ...  ...
# 1465          2        Medical              1            2061    Male  ...
# 1466          1        Medical              1            2062    Male  ...
# 1467          3  Life Sciences              1            2064    Male  ...
# 1468          3        Medical              1            2065    Male  ...
# 1469          3        Medical              1            2068    Male  ...
#
#       OverTime  PerformanceRating  StockOptionLevel TotalWorkingYears  \
# 0          Yes                  3                 0                 8
# 1           No                  4                 1                10
# 2          Yes                  3                 0                 7
# 3          Yes                  3                 0                 8
# 4           No                  3                 1                 6
# ...        ...                ...               ...               ...
# 1465        No                  3                 1                17
# 1466        No                  3                 1                 9
# 1467       Yes                  4                 1                 6
# 1468        No                  3                 0                17
# 1469        No                  3                 0                 6
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                         0               1               6
# 1                         3               3              10
# 2                         3               3               0
# 3                         3               3               8
# 4                         3               3               2
# ...                     ...             ...             ...
# 1465                      3               3               5
# 1466                      5               3               7
# 1467                      0               3               6
# 1468                      3               2               9
# 1469                      3               4               4
#
#       YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                       0                     5
# 1                      7                       1                     7
# 2                      0                       0                     0
# 3                      7                       3                     0
# 4                      2                       2                     2
# ...                  ...                     ...                   ...
# 1465                   2                       0                     3
# 1466                   7                       1                     7
# 1467                   2                       0                     3
# 1468                   6                       0                     8
# 1469                   3                       1                     2
#
# [1470 rows x 28 columns]

# %%
q = """
SELECT EmployeeNumber, Department, Age, Gender, Attrition
FROM employee;
"""
# retrieve requested table data

sales = pd.read_sql(q, conn)
sales
# save as dataframe named "sales"
# Out:
#       EmployeeNumber              Department  Age  Gender Attrition
# 0                  1                   Sales   41  Female       Yes
# 1                  2  Research & Development   49    Male        No
# 2                  4  Research & Development   37    Male       Yes
# 3                  5  Research & Development   33  Female        No
# 4                  7  Research & Development   27    Male        No
# ...              ...                     ...  ...     ...       ...
# 1465            2061  Research & Development   36    Male      None
# 1466            2062  Research & Development   39    Male        No
# 1467            2064  Research & Development   27    Male        No
# 1468            2065                   Sales   49    Male        No
# 1469            2068  Research & Development   34    Male        No
#
# [1470 rows x 5 columns]

# %% [markdown]
# Retrieve EmployeeNumber, EducationField, Age, Gender, and Attrition for employees in the Life Sciences field from the Employee table, save that information into a dataframe named ‘field’.

# %%
q = """
SELECT EmployeeNumber, EducationField, Age, Gender, Attrition
FROM employee
WHERE EducationField = "Life Sciences";
"""
# retrieve requested table data

field = pd.read_sql(q, conn)
field
# save as dataframe named "field"
# Out:
#      EmployeeNumber EducationField  Age  Gender Attrition
# 0                 1  Life Sciences   41  Female       Yes
# 1                 2  Life Sciences   49    Male        No
# 2                 5  Life Sciences   33  Female        No
# 3                 8  Life Sciences   32    Male        No
# 4                11  Life Sciences   30    Male        No
# ..              ...            ...  ...     ...       ...
# 601            2046  Life Sciences   45  Female      None
# 602            2048  Life Sciences   40    Male      None
# 603            2049  Life Sciences   35    Male      None
# 604            2052  Life Sciences   35  Female      None
# 605            2064  Life Sciences   27    Male        No
#
# [606 rows x 5 columns]

# %% [markdown]
# Save the two dataframes as tables in the database, and then join the tables on the primary key.

# %%
sales.to_sql("sales", conn)
# Out:
# 1470

# %%
field.to_sql("field", conn)
# Out:
# 606

# %%
q = """
SELECT name
FROM sqlite_master
WHERE type='table';
"""
# check that new tables are in database

pd.read_sql(q, conn)
# Out:
#        name
# 0  employee
# 1     sales
# 2     field

# %%
q = """
SELECT *
FROM sales s
INNER JOIN field f
ON s.EmployeeNumber = f.EmployeeNumber;
"""
# join tables on primary key EmployeeNumber

pd.read_sql(q, conn)
# Out:
#      index  EmployeeNumber              Department  Age  Gender Attrition  \
# 0        0               1                   Sales   41  Female       Yes
# 1        1               2  Research & Development   49    Male        No
# 2        3               5  Research & Development   33  Female        No
# 3        5               8  Research & Development   32    Male        No
# 4        7              11  Research & Development   30    Male        No
# ..     ...             ...                     ...  ...     ...       ...
# 601   1454            2046                   Sales   45  Female      None
# 602   1455            2048  Research & Development   40    Male      None
# 603   1456            2049  Research & Development   35    Male      None
# 604   1458            2052  Research & Development   35  Female      None
# 605   1467            2064  Research & Development   27    Male        No
#
#      index  EmployeeNumber EducationField  Age  Gender Attrition
# 0        0               1  Life Sciences   41  Female       Yes
# 1        1               2  Life Sciences   49    Male        No
# 2        2               5  Life Sciences   33  Female        No
# 3        3               8  Life Sciences   32    Male        No
# 4        4              11  Life Sciences   30    Male        No
# ..     ...             ...            ...  ...     ...       ...
# 601    601            2046  Life Sciences   45  Female      None
# 602    602            2048  Life Sciences   40    Male      None
# 603    603            2049  Life Sciences   35    Male      None
# 604    604            2052  Life Sciences   35  Female      None
# 605    605            2064  Life Sciences   27    Male        No
#
# [606 rows x 12 columns]
